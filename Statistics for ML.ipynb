# %% [markdown]
# # **An introduction to Pandas**
#
# In this notebook, we will be using 3 datasets:
# - a [**life expectancy**](https://drive.google.com/file/d/1KAe62s5H0FG0eF41DS1YAhNSuX6Tr4cn/view?usp=sharing) dataset from [Our World in Data](https://ourworldindata.org/life-expectancy)
# - a [**national GDP**](https://drive.google.com/file/d/1u9mwSNMy2h6y_8ZMcZILOJ_G2GpQjVW3/view?usp=sharing) dataset from [Our World in Data](https://ourworldindata.org/grapher/global-gdp-over-the-long-run)
# - a [**population**](https://drive.google.com/file/d/1LEUi881fmp2bfyIud-mazJlN03j-1Ub5/view?usp=sharing) dataset from [Our World in Data](https://ourworldindata.org/population-growth)
#
# Before you can run any cells, you need to upload the file to your Files in Colab.

# %% [markdown]
# ## **Importing Pandas**
# Before doing anything, we must **import the Pandas library**.
#
# > Sofware libraries bring additional funcitonality to our Python programs and are usually imported in this way.
#
# > You can call it anything, but giving it a short name such as `pd` will make it easy to remember and type later.

# %%
import pandas as pd

import numpy as np

# %% [markdown]
# ## **Loading data**
# Let's open a `csv` file with Pandas.
#
# > Pandas can load from various data sources with built-in functions such as `read_csv`, `read_excel`, `read_json` and even `read_html`

# %% [markdown]
# ### **pd.read_csv()**
#
# Here we are making a new variable called `df` and loading the data into it.
#
# > `df` is quite a common variable name as Pandas data structures are called **dataframes**.

# %%
df = pd.read_csv('life_expectancy.csv')

# %% [markdown]
# ## **Exploring the data**
#
# Let's have a look at the loaded data by calling the variable.
#
# > In **Jupyter Notebooks** you can call and display any variable simply by typing the name. In a normal Python program this would need to be done with `print(df)`
#
# > Dataframes are 2-dimensional tables. Each **column is called a series** and will have one type of data in it.

# %%
df
# Out:
#             Entity Code  Year  LifeExpectancy
# 0      Afghanistan  AFG  1950         27.7275
# 1      Afghanistan  AFG  1951         27.9634
# 2      Afghanistan  AFG  1952         28.4456
# 3      Afghanistan  AFG  1953         28.9304
# 4      Afghanistan  AFG  1954         29.2258
# ...            ...  ...   ...             ...
# 20750     Zimbabwe  ZWE  2017         60.7095
# 20751     Zimbabwe  ZWE  2018         61.4141
# 20752     Zimbabwe  ZWE  2019         61.2925
# 20753     Zimbabwe  ZWE  2020         61.1242
# 20754     Zimbabwe  ZWE  2021         59.2531
#
# [20755 rows x 4 columns]

# %% [markdown]
# ### **df.head()**
#
# We can also just show the first few rows with `df_head()` method.
#
# > The power of Pandas is in the built-in methods we can call on a dataframe.
#
# > Pandas methods usually follow this format: `df.method()`, where `df` is your dataframe variable and `method()` is the name of the method. The brackets are used to sometimes pass settings to the method.

# %%
# Calling the head() method on our dataframe df
df.head(10)
# Out:
#         Entity Code  Year  LifeExpectancy
# 0  Afghanistan  AFG  1950         27.7275
# 1  Afghanistan  AFG  1951         27.9634
# 2  Afghanistan  AFG  1952         28.4456
# 3  Afghanistan  AFG  1953         28.9304
# 4  Afghanistan  AFG  1954         29.2258
# 5  Afghanistan  AFG  1955         29.9206
# 6  Afghanistan  AFG  1956         30.4078
# 7  Afghanistan  AFG  1957         30.9458
# 8  Afghanistan  AFG  1958         31.5066
# 9  Afghanistan  AFG  1959         32.0386

# %% [markdown]
# ### **df.tail()**
# We can also get the last few:

# %%
df.tail()
# Out:
#          Entity Code  Year  LifeExpectancy
# 20750  Zimbabwe  ZWE  2017         60.7095
# 20751  Zimbabwe  ZWE  2018         61.4141
# 20752  Zimbabwe  ZWE  2019         61.2925
# 20753  Zimbabwe  ZWE  2020         61.1242
# 20754  Zimbabwe  ZWE  2021         59.2531

# %% [markdown]
# ### **df.sample()**
#
# You can even call a random sample:
#
# > Change 10 to your desired sample size.

# %%
df.sample(20)
# Out:
#                            Entity Code  Year  LifeExpectancy
# 3284     Central African Republic  CAF  1965       41.928800
# 15875  Saint Martin (French part)  MAF  2021       80.378800
# 376                      Americas  NaN  1955       60.246532
# 18997                Turkmenistan  TKM  1958       52.585800
# 7445                       Guinea  GIN  1955       35.903100
# 17163                     Somalia  SOM  1983       48.166300
# 20369           Wallis and Futuna  WLF  2003       75.885000
# 1837                      Belgium  BEL  2020       80.788400
# 4870           Dominican Republic  DOM  2011       72.221200
# 18306                      Taiwan  TWN  2000       76.199800
# 14513                   Palestine  PSE  2004       71.182300
# 18209                       Syria  SYR  1975       63.537800
# 2369                     Botswana  BWA  1970       55.197500
# 15646                Saint Helena  SHN  2008       75.770600
# ...

# %% [markdown]
# ### **df.info()**
#
# It is sometimes also useful to get a sense of the structure and layout of a dataframe.
#
# Here we can see the column names, how many non-null values there are for that column (or series) and what the expected datatype is.
#
# > Data types can be:
# - **object**: Represents strings (text).
# - **int64**: Represents integers (whole numbers).
# - **float64**: Represents floating-point numbers (numbers with decimals).
# - **bool**: Represents boolean values (True or False).
# - **datetime64**: Represents dates and times.
# - **timedelta[ns]**: Represents differences between dates and times.
# - **category**: Represents categorical data (a fixed set of possible values).

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20755 entries, 0 to 20754
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Entity          20755 non-null  object
#  1   Code            19061 non-null  object
#  2   Year            20755 non-null  int64
#  3   LifeExpectancy  20755 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 648.7+ KB

# %% [markdown]
# ### **df.describe()**
#
# A very useful built-in method is `describe()`.
# It will give descriptive statistical information for any numerical series in the table - including the `count`, `mean`, `min`, `max` and `std` (standard deviation).
#
# > This method will only work on the numerical series and will skip any object series.

# %%
df.describe()
# Out:
#                Year  LifeExpectancy
# count  20755.000000    20755.000000
# mean    1975.730234       61.617992
# std       38.423230       12.917682
# min     1543.000000       11.995100
# 25%     1961.000000       52.185850
# 50%     1981.000000       64.060000
# 75%     2001.000000       71.822250
# max     2021.000000       86.542400

# %% [markdown]
# ## **Selecting Data**
#
# There are a few different ways to select data in Pandas.

# %% [markdown]
# ### **df['series']**
#
# The first way is to select all the values in a series. We can specify the series with square brackets: `df['series']` - where series is the column name. Here we view all the values in the `Entity` series.

# %%
df['Entity']
# Out:
# 0        Afghanistan
# 1        Afghanistan
# 2        Afghanistan
# 3        Afghanistan
# 4        Afghanistan
#             ...
# 20750       Zimbabwe
# 20751       Zimbabwe
# 20752       Zimbabwe
# 20753       Zimbabwe
# 20754       Zimbabwe
# Name: Entity, Length: 20755, dtype: object

# %% [markdown]
# We can also get multiple columns at once:
#
# > Note the double brackets when specifying multiple columns.

# %%
df[['Entity','Code']]
# Out:
#             Entity Code
# 0      Afghanistan  AFG
# 1      Afghanistan  AFG
# 2      Afghanistan  AFG
# 3      Afghanistan  AFG
# 4      Afghanistan  AFG
# ...            ...  ...
# 20750     Zimbabwe  ZWE
# 20751     Zimbabwe  ZWE
# 20752     Zimbabwe  ZWE
# 20753     Zimbabwe  ZWE
# 20754     Zimbabwe  ZWE
#
# [20755 rows x 2 columns]

# %% [markdown]
# ### **df['series'].unique()**
#
#
# Datasets can often have repeated values in a series and it can be useful to get a sense of the unique values.
#
# > Here we are looking at all the countries in the `Entity` column.

# %%
df['Entity'].unique()
# Out:
# array(['Afghanistan', 'Africa', 'Albania', 'Algeria', 'American Samoa',
#        'Americas', 'Andorra', 'Angola', 'Anguilla', 'Antigua and Barbuda',
#        'Argentina', 'Armenia', 'Aruba', 'Asia', 'Australia', 'Austria',
#        'Azerbaijan', 'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados',
#        'Belarus', 'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan',
#        'Bolivia', 'Bonaire Sint Eustatius and Saba',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei', 'Bulgaria', 'Burkina Faso',
#        'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde',
#        'Cayman Islands', 'Central African Republic', 'Chad', 'Chile',
#        'China', 'Colombia', 'Comoros', 'Congo', 'Cook Islands',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao',
#        'Cyprus', 'Czechia', 'Democratic Republic of Congo', 'Denmark',
#        'Djibouti', 'Dominica', 'Dominican Republic', 'East Timor',
# ...

# %% [markdown]
# ### **df['series'].max()**
#
# We can find the maximum value in a numerical series with the `max()` method.

# %%
df['Year'].max()
# Out:
# 2021

# %% [markdown]
# ### **df['series'].min()**
#
# > Here we can see the lowest year in the dataset is 1543!

# %%
df['Year'].min()
# Out:
# 1543

# %% [markdown]
# ### **df.loc()**
#
# We can select specific rows and columns with the `loc()` method.
# The parameters can be numbers - indicating the index of the row or column, or a named index.
#
# > You can pass a single row index. In this case we are passing `0` - which means the first row.
#
# > **Remember in most programming languages lists usually start count at 0 by default.**

# %%
df.loc[10]
# Out:
# Entity            Afghanistan
# Code                      AFG
# Year                     1960
# LifeExpectancy        32.5346
# Name: 10, dtype: object

# %% [markdown]
# > You can also pass a row and a column which will return a single value.

# %%
df.loc[0,'Entity']

# %% [markdown]
# Or multiple rows and columns:
#
# > Note the brackets separating rows and columns.

# %%
df.loc[[0,1,2],['Entity','Code']]

# %% [markdown]
# Or even ranges:
#
# > In this case we are selecting from row 2 to row 5.

# %%
df.loc[2:5,['Entity','Code']]

# %% [markdown]
# Or everything from row 500 onwards:

# %%
df.loc[500:,['Entity','Code']]

# %% [markdown]
# ## **Filtering our data**
#
# Pandas has various methods and techniques to filter and query our data.

# %% [markdown]
# ### **df.query()**
#
# The `query()` method is very powerful and can be extended and combined to filter the dataframe in any number of ways.
#
# Here we are looking for rows that have 1543 as a Year value:
#
# > Note the == double equal operator.
#
# > **See more on operators at the end of this notebook.**

# %%
df.query('Year == 1543')
# Out:
#                Entity Code  Year  LifeExpectancy
# 19539  United Kingdom  GBR  1543           33.94

# %% [markdown]
# The `<` operator will return any rows where `Year` is "smaller" than 1800.

# %%
df.query('Year < 1800')
# Out:
#                Entity      Code  Year  LifeExpectancy
# 144            Africa       NaN  1770           26.40
# 365          Americas       NaN  1770           34.80
# 1035             Asia       NaN  1770           27.50
# 4664          Denmark       DNK  1775           33.00
# 5743           Europe       NaN  1770           34.30
# ...               ...       ...   ...             ...
# 19587  United Kingdom       GBR  1783           35.81
# 19588  United Kingdom       GBR  1788           38.97
# 19589  United Kingdom       GBR  1793           37.92
# 19590  United Kingdom       GBR  1798           38.93
# 20532           World  OWID_WRL  1770           28.50
#
# [112 rows x 4 columns]

# %% [markdown]
# ### **Chaining Pandas methods**
#
# Pandas methods can be used one after the other in a single execution.
#
# Here we are querying the dataframe for rows where `Year` is before 1800 and we are just looking at the `Entity` column and seeing what unique values there are in that subset.

# %%
df.query('Year < 1800')['Entity'].unique()
# Out:
# array(['Africa', 'Americas', 'Asia', 'Denmark', 'Europe', 'Finland',
#        'Sweden', 'United Kingdom', 'World'], dtype=object)

# %% [markdown]
# ### **df['series].nunique()**
#
# This simply returns the count of the uniques for a series.

# %%
df.query('Year < 1800')['Entity'].nunique()

# %% [markdown]
# ### **More ways to use query()**
#
# When searching for strings, we use quotes to isolate the string.

# %%
df.query('Entity == "Namibia"')
# Out:
#         Entity Code  Year  LifeExpectancy
# 12766  Namibia  NAM  1950         41.5307
# 12767  Namibia  NAM  1951         41.7739
# 12768  Namibia  NAM  1952         42.3996
# 12769  Namibia  NAM  1953         43.0004
# 12770  Namibia  NAM  1954         43.6840
# ...        ...  ...   ...             ...
# 12833  Namibia  NAM  2017         62.2931
# 12834  Namibia  NAM  2018         62.5859
# 12835  Namibia  NAM  2019         63.0750
# 12836  Namibia  NAM  2020         62.8290
# 12837  Namibia  NAM  2021         59.2690
#
# [72 rows x 4 columns]

# %% [markdown]
# Query with **multiple** criteria:
#
# Here we are searching for rows where `Entity` is "Namibia" and `Year` is 2010.

# %%
df.query('Entity == "Namibia" & Year == 2010')
# Out:
#         Entity Code  Year  LifeExpectancy
# 12826  Namibia  NAM  2010         56.0153

# %% [markdown]
# Queries can be as simple or complicated as you like:
#
# Here we are searching for rows where `Year` is 2010 and `Entity` is "Namibia" OR (|) rows where `Year` is 2010 and `Entity` is "Zimbabwe".

# %%
df.query('Year == 2010 & Entity == "Namibia" | Year == 2010 & Entity == "Zimbabwe"')
# Out:
#          Entity Code  Year  LifeExpectancy
# 12826   Namibia  NAM  2010         56.0153
# 20743  Zimbabwe  ZWE  2010         50.6523

# %% [markdown]
# This could also be rewritten as:
#
# > Note the brackets around our `Entity` query. The brackets ensure that that is considered as a single concept.

# %%
df.query('(Entity == "Namibia" | Entity == "Zimbabwe") & Year == 2010')
# Out:
#          Entity Code  Year  LifeExpectancy
# 12826   Namibia  NAM  2010         56.0153
# 20743  Zimbabwe  ZWE  2010         50.6523

# %% [markdown]
# So we can also read multiple years for instance:

# %%
df.query('(Entity == "Namibia" | Entity == "Zimbabwe") & Year > 1950')
# Out:
#          Entity Code  Year  LifeExpectancy
# 12767   Namibia  NAM  1951         41.7739
# 12768   Namibia  NAM  1952         42.3996
# 12769   Namibia  NAM  1953         43.0004
# 12770   Namibia  NAM  1954         43.6840
# 12771   Namibia  NAM  1955         44.2882
# ...         ...  ...   ...             ...
# 20750  Zimbabwe  ZWE  2017         60.7095
# 20751  Zimbabwe  ZWE  2018         61.4141
# 20752  Zimbabwe  ZWE  2019         61.2925
# 20753  Zimbabwe  ZWE  2020         61.1242
# 20754  Zimbabwe  ZWE  2021         59.2531
#
# [142 rows x 4 columns]

# %% [markdown]
# ### **More ways to filter data**
#
# The `query()` method is very useful, but there are other ways to query the data. We can use series queries directly:

# %%
df[df['Year'] == 1543]
# Out:
#                Entity Code  Year  LifeExpectancy
# 19539  United Kingdom  GBR  1543           33.94

# %% [markdown]
# Or with multiple criteria.
#
# > Note the brackets used to separate criteria.

# %%
df[(df['Entity'] == 'Namibia') & (df['Year'] == 2010)]

# %% [markdown]
# > Again, note the use of the brackets to separate criteria.

# %%
df[((df['Entity'] == 'Namibia') | (df['Entity'] == 'Zimbabwe')) & (df['Year'] == 2010)]

# %% [markdown]
# ## **Plotting the data**
#
# Plotting our datasets is essential to understand and analyse our datasets.
#
# > We will be looking at a few different plotting libraries and options. By default Pandas uses the `matplotlib` library.

# %% [markdown]
# ### **df.plot()**
#
# Pandas `plot()` defaults to line, but can produce a variety of chart types:
# `line`, `bar`, `barh`, `hist`, `box`, `kde`, `density`, `area`, `pie`, `scatter` and `hexbin`
#
# > Here we can see again how we can chain Pandas methods. We are querying and plotting in one execution.

# %%
df.query('Entity == "Namibia"').plot(x='Year', y='LifeExpectancy')
# Out:
# <Axes: xlabel='Year'>

# %% [markdown]
# ### **Fixing bad charts**
#
# Before plotting data - especially timeseries data - it is essential to sort the data. Consider this problem below:
#
# Here we are querying the data for `Entity` == "United Kingdom", but the chart looks very strange.

# %%
df.query('Entity == "United Kingdom"').plot(x='Year', y='LifeExpectancy')

# %% [markdown]
# If we investigate the queried data, we can see the years are not in order:

# %%
df.query('Entity == "United Kingdom"')

# %% [markdown]
# ### **df.sort_values('series')**
#
# Here we sorting the values before plotting.
#
# > Remember at no point have we actually made any changes to our dataframe. These queries and sortings are done at runtime (when executing the cell) and doesn't affect the original dataframe.
#
# > At any point in time, we **CAN** set our query to a new variable or update our original variable. ie `df = df.qeury('Entity == "Namibia")` will mean the `df` will only now contain "Namibia".
#
# > This might be very useful to store different versions of the data and save time (and complexity) on retyping queries.

# %%
df.query('Entity == "United Kingdom"').sort_values('Year').plot(x='Year', y='LifeExpectancy')

# %% [markdown]
# ### **Combining plots**
#
# There is more than one way to combine plots. The first method is essentially this:
#
# - Create a plot and store it in a variable.
# - Make a second plot and use the first plot as the axes. (`ax=base_chart`)

# %%
base_chart = df.query('Entity == "United Kingdom"').sort_values('Year').plot(x='Year', y='LifeExpectancy')
df.query('Entity == "Namibia"').sort_values('Year').plot(x='Year', y='LifeExpectancy', ax=base_chart)
# Out:
# <Axes: xlabel='Year'>

# %% [markdown]
# We can change our queries to line up the charts a bit better:

# %%
base_chart = df.query('Entity == "United Kingdom" & Year > 1949').sort_values('Year').plot(x='Year', y='LifeExpectancy', label="UK")
df.query('Entity == "Namibia" & Year > 1949').sort_values('Year').plot(x='Year', y='LifeExpectancy', ax=base_chart, label="Namibia")
# Out:
# <Axes: xlabel='Year'>

# %% [markdown]
# The problem with this approach is that we would need to create a chart for every Entity and this might not be possible when comparing more variables.

# %% [markdown]
# ### **df.pivot()**
#
# A better way to approach charting on a dataset might be to pivot our data.
#
# > Just like in a spreadsheet, we choose our index, columns and values.

# %%
df_pivot = df.pivot(index='Year', columns='Entity', values='LifeExpectancy')
df_pivot
# Out:
# Entity  Afghanistan   Africa  Albania  Algeria  American Samoa   Americas  \
# Year
# 1543            NaN      NaN      NaN      NaN             NaN        NaN
# 1548            NaN      NaN      NaN      NaN             NaN        NaN
# 1553            NaN      NaN      NaN      NaN             NaN        NaN
# 1558            NaN      NaN      NaN      NaN             NaN        NaN
# 1563            NaN      NaN      NaN      NaN             NaN        NaN
# ...             ...      ...      ...      ...             ...        ...
# 2017        63.0160  61.9858  79.0473  75.7428         72.4830  76.359490
# 2018        63.0810  62.3435  79.1838  76.0656         72.4915  76.487580
# 2019        63.5645  62.6880  79.2825  76.4742         72.3023  76.663250
# 2020        62.5751  62.2342  76.9893  74.4528         72.4432  74.835236
# 2021        61.9824  61.6609  76.4626  76.3767         72.5398  74.189156
#
# ...

# %%
df_pivot.plot(legend=False)
# Out:
# <Axes: xlabel='Year'>

# %% [markdown]
# Let's filter it to our selected countries and time range:

# %%
df_pivot = df.query('(Entity == "United Kingdom" | Entity == "Namibia") & Year > 1949').pivot(index='Year', columns='Entity', values='LifeExpectancy')
df_pivot
# Out:
# Entity  Namibia  United Kingdom
# Year
# 1950    41.5307         68.6310
# 1951    41.7739         68.2352
# 1952    42.3996         69.5176
# 1953    43.0004         69.7967
# 1954    43.6840         70.1646
# ...         ...             ...
# 2017    62.2931         81.1684
# 2018    62.5859         81.1254
# 2019    63.0750         81.7250
# 2020    62.8290         80.4345
# 2021    59.2690         80.7422
#
# [72 rows x 2 columns]

# %%
df_pivot.plot()
# Out:
# <Axes: xlabel='Year'>

# %% [markdown]
# ### **Using variables in filters**
#
# Suppose we wanted to have more countries, we could make the filtering a bit cleaner and simpler like this:

# %%
countries = ["United Kingdom", "Namibia", "South Africa", "Nigeria", "Kenya"]
df_pivot = df.query('Entity == @countries & Year > 1949').pivot(index='Year', columns='Entity', values='LifeExpectancy')
df_pivot
# Out:
# Entity    Kenya  Namibia  Nigeria  South Africa  United Kingdom
# Year
# 1950    38.9024  41.5307  35.8097       43.4715         68.6310
# 1951    39.0919  41.7739  35.9247       44.1756         68.2352
# 1952    38.9473  42.3996  36.0935       45.0614         69.5176
# 1953    40.3157  43.0004  36.3435       46.0056         69.7967
# 1954    41.6892  43.6840  36.4453       47.1206         70.1646
# ...         ...      ...      ...           ...             ...
# 2017    62.4808  62.2931  52.3052       65.4020         81.1684
# 2018    62.6765  62.5859  52.5536       65.6743         81.1254
# 2019    62.9432  63.0750  52.9104       66.1750         81.7250
# 2020    62.6755  62.8290  52.8870       65.2522         80.4345
# 2021    61.4270  59.2690  52.6760       62.3410         80.7422
#
# [72 rows x 5 columns]

# %%
df_pivot.plot()
# Out:
# <Axes: xlabel='Year'>

# %% [markdown]
# ### **Styling the plot**

# %%
df_pivot_plot = df_pivot.plot(title="Life Expectancy", ylabel="Life Expectancy (Years)", fontsize=8, figsize=(12, 6))
df_pivot_plot.grid(color='#eee', linestyle='--', linewidth=0.5)
df_pivot_plot.set_facecolor('#fefefe')

# %% [markdown]
# ### **Adding reference lines**
#
# Use the `axvline()` or `axhline()` method to add a reference line.

# %%
df_pivot_plot = df_pivot.plot(title="Life Expectancy", ylabel="Life Expectancy (Years)", fontsize=8, figsize=(12, 6))
df_pivot_plot.grid(color='#eee', linestyle='--', linewidth=0.5)
df_pivot_plot.set_facecolor('#fefefe')
df_pivot_plot.axvline(x=2002, color='#333', linestyle='--', linewidth=0.8)
df_pivot_plot.axhline(y=55, color='#333', linestyle='--', linewidth=0.8)

# %% [markdown]
# ### **More styling**
#
# You can change the colour of individual lines by adding a `color` parameter to the `plot()`

# %%
df_pivot_plot = df_pivot.plot(title="Life Expectancy", ylabel="Life Expectancy (Years)", fontsize=8, figsize=(12, 6), color=['grey','grey','grey','red'])
df_pivot_plot.grid(color='#eee', linestyle='--', linewidth=0.5)
df_pivot_plot.set_facecolor('#fefefe')

# %% [markdown]
# ### **Conditional styling with code**
#
# We might need to style individual lines and can potentially do it like this:

# %%
colors = ['red' if country == "Nigeria" else 'grey' for country in df_pivot.columns]
df_pivot_plot = df_pivot.plot(title="Life Expectancy", ylabel="Life Expectancy (Years)", fontsize=8, figsize=(12, 6), color=colors)

# %% [markdown]
# ## **Combining datasets**
#
# The ability to combine datasets is essential for any meaningful data analysis or exploration. This is also one of Pandas key strengths and it is perhaps even better at it than your usual spreadsheet.

# %% [markdown]
# ### **Load another dataset to combine**
#
# Let's load another set and examine it.

# %%
gdp_df = pd.read_csv('national_gdp.csv')

# %%
gdp_df
# Out:
#             Entity Code  Year  GDP (constant 2015 US$)
# 0      Afghanistan  AFG  2002               7228796000
# 1      Afghanistan  AFG  2003               7867263500
# 2      Afghanistan  AFG  2004               7978515500
# 3      Afghanistan  AFG  2005               8874481000
# 4      Afghanistan  AFG  2006               9349922000
# ...            ...  ...   ...                      ...
# 10935     Zimbabwe  ZWE  2018              22015179000
# 10936     Zimbabwe  ZWE  2019              20621079000
# 10937     Zimbabwe  ZWE  2020              19009139000
# 10938     Zimbabwe  ZWE  2021              20618836000
# 10939     Zimbabwe  ZWE  2022              21963674000
#
# [10940 rows x 4 columns]

# %% [markdown]
# Here we can see the first year in the set is 1960 and the last year is 2022.

# %%
gdp_df.describe()
# Out:
#                Year  GDP (constant 2015 US$)
# count  10940.000000             1.094000e+04
# mean    1995.357038             1.058506e+12
# std       17.244867             5.011738e+12
# min     1960.000000             2.156211e+07
# 25%     1982.000000             4.281527e+09
# 50%     1997.000000             2.078622e+10
# 75%     2010.000000             1.793602e+11
# max     2022.000000             8.999466e+13

# %% [markdown]
# ### **df.merge()**
#
# The Pandas `merge()` method allows us to merge datframes on one or more columns.
#
# Let's look at our original set again:

# %%
df
# Out:
#             Entity Code  Year  LifeExpectancy
# 0      Afghanistan  AFG  1950         27.7275
# 1      Afghanistan  AFG  1951         27.9634
# 2      Afghanistan  AFG  1952         28.4456
# 3      Afghanistan  AFG  1953         28.9304
# 4      Afghanistan  AFG  1954         29.2258
# ...            ...  ...   ...             ...
# 20750     Zimbabwe  ZWE  2017         60.7095
# 20751     Zimbabwe  ZWE  2018         61.4141
# 20752     Zimbabwe  ZWE  2019         61.2925
# 20753     Zimbabwe  ZWE  2020         61.1242
# 20754     Zimbabwe  ZWE  2021         59.2531
#
# [20755 rows x 4 columns]

# %% [markdown]
# ### **Merging methods**
#
# We want to merge on Code and Year, so we can specify both columns in the `on` parameter. We are choosing `left` for the `how` parameter. This means it will keep everything in the left dataframe (in this case `df` and add to it values from the right dataframe (`gdp_df`) where possible.
#
# ![Joins](https://www.datasciencemadesimple.com/wp-content/uploads/2017/09/join-or-merge-in-python-pandas-1.png)

# %%
merged_df = pd.merge(df, gdp_df, on=['Code', 'Year'], how='left')
merged_df
# Out:
#           Entity_x Code  Year  LifeExpectancy  Entity_y  \
# 0      Afghanistan  AFG  1950         27.7275       NaN
# 1      Afghanistan  AFG  1951         27.9634       NaN
# 2      Afghanistan  AFG  1952         28.4456       NaN
# 3      Afghanistan  AFG  1953         28.9304       NaN
# 4      Afghanistan  AFG  1954         29.2258       NaN
# ...            ...  ...   ...             ...       ...
# 34790     Zimbabwe  ZWE  2017         60.7095  Zimbabwe
# 34791     Zimbabwe  ZWE  2018         61.4141  Zimbabwe
# 34792     Zimbabwe  ZWE  2019         61.2925  Zimbabwe
# 34793     Zimbabwe  ZWE  2020         61.1242  Zimbabwe
# 34794     Zimbabwe  ZWE  2021         59.2531  Zimbabwe
#
#        GDP (constant 2015 US$)
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ...                        ...
# 34790             2.096487e+10
# 34791             2.201518e+10
# ...

# %% [markdown]
# ### **Fixing a bad merge**
#
# The merged dataframe has **34795 rows**. When doing a left merge we would expect it to have exactly the same amount of rows as the left dataframe - **20755**. So what went wrong?
#
# Here we can see that there are 20755 rows, but not all of them are **non-null** for the `Code` column.
#
# Similarly on `gdp_df` we can see there are quite a few **non-null** entries for the `Code` column.
#
# the problem with that is that we can't merge on **nulls** as they will match multiple times. Ending up with a bigger dataframe as we saw.

# %%
df['Code'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 20755 entries, 0 to 20754
# Series name: Code
# Non-Null Count  Dtype
# --------------  -----
# 19061 non-null  object
# dtypes: object(1)
# memory usage: 162.3+ KB

# %%
gdp_df['Code'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 10940 entries, 0 to 10939
# Series name: Code
# Non-Null Count  Dtype
# --------------  -----
# 10162 non-null  object
# dtypes: object(1)
# memory usage: 85.6+ KB

# %% [markdown]
# ### **df['series].isnull()**
#
# In this case, let's see what Entities have Codes with **null**:

# %%
df[df['Code'].isnull()]
# Out:
#                               Entity Code  Year  LifeExpectancy
# 72                            Africa  NaN  1950         37.6235
# 73                            Africa  NaN  1951         37.9309
# 74                            Africa  NaN  1952         38.4430
# 75                            Africa  NaN  1953         38.9152
# 76                            Africa  NaN  1954         39.2991
# ...                              ...  ...   ...             ...
# 19941  Upper-middle-income countries  NaN  2017         75.9064
# 19942  Upper-middle-income countries  NaN  2018         76.2589
# 19943  Upper-middle-income countries  NaN  2019         76.4784
# 19944  Upper-middle-income countries  NaN  2020         75.7449
# 19945  Upper-middle-income countries  NaN  2021         75.2817
#
# [1694 rows x 4 columns]

# %%
df[df['Code'].isnull()]['Entity'].unique()
# Out:
# array(['Africa', 'Americas', 'Asia', 'England and Wales', 'Europe',
#        'High-income countries', 'Land-locked Developing Countries (LLDC)',
#        'Latin America and the Caribbean', 'Least developed countries',
#        'Less developed regions',
#        'Less developed regions, excluding China',
#        'Less developed regions, excluding least developed countries',
#        'Low-income countries', 'Lower-middle-income countries',
#        'Middle-income countries', 'More developed regions',
#        'No income group available', 'Northern America',
#        'Northern Ireland', 'Oceania', 'Scotland',
#        'Small Island Developing States (SIDS)',
#        'Upper-middle-income countries'], dtype=object)

# %%
gdp_df[gdp_df['Code'].isnull()]
# Out:
#                               Entity Code  Year  GDP (constant 2015 US$)
# 2755      East Asia and Pacific (WB)  NaN  1960            1160049600000
# 2756      East Asia and Pacific (WB)  NaN  1961            1203765100000
# 2757      East Asia and Pacific (WB)  NaN  1962            1269959400000
# 2758      East Asia and Pacific (WB)  NaN  1963            1369225600000
# 2759      East Asia and Pacific (WB)  NaN  1964            1513495900000
# ...                              ...  ...   ...                      ...
# 10535  Upper-middle-income countries  NaN  2018           23655490000000
# 10536  Upper-middle-income countries  NaN  2019           24630576000000
# 10537  Upper-middle-income countries  NaN  2020           24462263000000
# 10538  Upper-middle-income countries  NaN  2021           26317712000000
# 10539  Upper-middle-income countries  NaN  2022           27139689000000
#
# [778 rows x 4 columns]

# %%
gdp_df[gdp_df['Code'].isnull()]['Entity'].unique()
# Out:
# array(['East Asia and Pacific (WB)', 'Europe and Central Asia (WB)',
#        'European Union (27)', 'Faeroe Islands', 'High-income countries',
#        'Latin America and Caribbean (WB)', 'Low-income countries',
#        'Lower-middle-income countries',
#        'Middle East and North Africa (WB)', 'Middle-income countries',
#        'North America (WB)', 'South Asia (WB)', 'Sub-Saharan Africa (WB)',
#        'Upper-middle-income countries'], dtype=object)

# %% [markdown]
# ### **Dropping the null rows**
#
# Let's get rid of all the null rows with a `notnull()` method.
#
# Here we are making a new datafame and saying it is everthing where Code is not null.
#
# > We're making a new variable so that we can always get back to the original `df` if we want to.

# %%
df_filtered = df[df['Code'].notnull()]
df_filtered
# Out:
#             Entity Code  Year  LifeExpectancy
# 0      Afghanistan  AFG  1950         27.7275
# 1      Afghanistan  AFG  1951         27.9634
# 2      Afghanistan  AFG  1952         28.4456
# 3      Afghanistan  AFG  1953         28.9304
# 4      Afghanistan  AFG  1954         29.2258
# ...            ...  ...   ...             ...
# 20750     Zimbabwe  ZWE  2017         60.7095
# 20751     Zimbabwe  ZWE  2018         61.4141
# 20752     Zimbabwe  ZWE  2019         61.2925
# 20753     Zimbabwe  ZWE  2020         61.1242
# 20754     Zimbabwe  ZWE  2021         59.2531
#
# [19061 rows x 4 columns]

# %% [markdown]
# We'll do the same for the other dataframe:

# %%
gdp_df_filtered = gdp_df[gdp_df['Code'].notnull()]
gdp_df_filtered
# Out:
#             Entity Code  Year  GDP (constant 2015 US$)
# 0      Afghanistan  AFG  2002               7228796000
# 1      Afghanistan  AFG  2003               7867263500
# 2      Afghanistan  AFG  2004               7978515500
# 3      Afghanistan  AFG  2005               8874481000
# 4      Afghanistan  AFG  2006               9349922000
# ...            ...  ...   ...                      ...
# 10935     Zimbabwe  ZWE  2018              22015179000
# 10936     Zimbabwe  ZWE  2019              20621079000
# 10937     Zimbabwe  ZWE  2020              19009139000
# 10938     Zimbabwe  ZWE  2021              20618836000
# 10939     Zimbabwe  ZWE  2022              21963674000
#
# [10162 rows x 4 columns]

# %% [markdown]
# ### **df.merge()**
#
# Now the merge should work:

# %%
merged_df = pd.merge(df_filtered, gdp_df_filtered, on=['Code', 'Year'], how='left')
merged_df
# Out:
#           Entity_x Code  Year  LifeExpectancy  Entity_y  \
# 0      Afghanistan  AFG  1950         27.7275       NaN
# 1      Afghanistan  AFG  1951         27.9634       NaN
# 2      Afghanistan  AFG  1952         28.4456       NaN
# 3      Afghanistan  AFG  1953         28.9304       NaN
# 4      Afghanistan  AFG  1954         29.2258       NaN
# ...            ...  ...   ...             ...       ...
# 19056     Zimbabwe  ZWE  2017         60.7095  Zimbabwe
# 19057     Zimbabwe  ZWE  2018         61.4141  Zimbabwe
# 19058     Zimbabwe  ZWE  2019         61.2925  Zimbabwe
# 19059     Zimbabwe  ZWE  2020         61.1242  Zimbabwe
# 19060     Zimbabwe  ZWE  2021         59.2531  Zimbabwe
#
#        GDP (constant 2015 US$)
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ...                        ...
# 19056             2.096487e+10
# 19057             2.201518e+10
# ...

# %% [markdown]
# ### **Renaming columns**
#
# Let's rename the `GDP (constant 2015 US$)` column.

# %%
merged_df.rename(columns={'GDP (constant 2015 US$)': 'GDP'}, inplace=True)
merged_df
# Out:
#           Entity_x Code  Year  LifeExpectancy  Entity_y           GDP
# 0      Afghanistan  AFG  1950         27.7275       NaN           NaN
# 1      Afghanistan  AFG  1951         27.9634       NaN           NaN
# 2      Afghanistan  AFG  1952         28.4456       NaN           NaN
# 3      Afghanistan  AFG  1953         28.9304       NaN           NaN
# 4      Afghanistan  AFG  1954         29.2258       NaN           NaN
# ...            ...  ...   ...             ...       ...           ...
# 19056     Zimbabwe  ZWE  2017         60.7095  Zimbabwe  2.096487e+10
# 19057     Zimbabwe  ZWE  2018         61.4141  Zimbabwe  2.201518e+10
# 19058     Zimbabwe  ZWE  2019         61.2925  Zimbabwe  2.062108e+10
# 19059     Zimbabwe  ZWE  2020         61.1242  Zimbabwe  1.900914e+10
# 19060     Zimbabwe  ZWE  2021         59.2531  Zimbabwe  2.061884e+10
#
# [19061 rows x 6 columns]

# %% [markdown]
# ### **Dropping columns**
#
# Let's get rid of the second Entity_y column:

# %%
merged_df = merged_df.drop(columns=['Entity_y'])
merged_df = merged_df.rename(columns={'Entity_x': 'Entity'})
merged_df
# Out:
#             Entity Code  Year  LifeExpectancy           GDP
# 0      Afghanistan  AFG  1950         27.7275           NaN
# 1      Afghanistan  AFG  1951         27.9634           NaN
# 2      Afghanistan  AFG  1952         28.4456           NaN
# 3      Afghanistan  AFG  1953         28.9304           NaN
# 4      Afghanistan  AFG  1954         29.2258           NaN
# ...            ...  ...   ...             ...           ...
# 19056     Zimbabwe  ZWE  2017         60.7095  2.096487e+10
# 19057     Zimbabwe  ZWE  2018         61.4141  2.201518e+10
# 19058     Zimbabwe  ZWE  2019         61.2925  2.062108e+10
# 19059     Zimbabwe  ZWE  2020         61.1242  1.900914e+10
# 19060     Zimbabwe  ZWE  2021         59.2531  2.061884e+10
#
# [19061 rows x 5 columns]

# %% [markdown]
# ### **Plotting the data**
#
# Let's see every country in the dataset's life-expectancy against their GDP in 2020

# %%
merged_df.query('Year == 2020').plot(kind='scatter',
    x='GDP',
    y='LifeExpectancy',
    alpha=0.7,
    figsize=(10, 6),
    logx=True,
    title='Life Expectancy vs. GDP in 2020',
    xlabel='GDP (constant 2015 US$)',
    ylabel='Life Expectancy')
# Out:
# <Axes: title={'center': 'Life Expectancy vs. GDP in 2020'}, xlabel='GDP (constant 2015 US$)', ylabel='Life Expectancy'>

# %% [markdown]
# ### **Plotting the data with Plotly**
#
# Pandas uses Matplotlib as its default plotting library, but there are many other plotting libraries, each with different strengths.
#
# > Plotting libraries include: [Matplotlib](https://matplotlib.org/), [Seaborn](https://seaborn.pydata.org/), [Plotly](https://dash.plotly.com/), [Plotnine](https://plotnine.org/), [Bokeh](https://bokeh.org/) and [Altair](https://altair-viz.github.io/).

# %%
import plotly.express as px

fig = px.scatter(merged_df.query('Year == 2020'),
          x='GDP',
          y='LifeExpectancy',
          hover_name='Entity',
          log_x=True,
          title='Life Expectancy vs. GDP in 2020',
          labels={
              'GDP': 'GDP (constant 2015 US$)',
              'LifeExpectancy': 'Life Expectancy'
          },
          width=1000,
          height=800)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### **Plotting the data with Bokeh**
#
# Here's the same chart using Bokeh.

# %%
from bokeh.plotting import figure, show, output_notebook
from bokeh.models import HoverTool

output_notebook()

p = figure(title='Life Expectancy vs. GDP in 2020',
           x_axis_label='GDP (constant 2015 US$)',
           y_axis_label='Life Expectancy',
           x_axis_type="log",
           width=1000,
           height=800)

scatter = p.scatter(x='GDP', y='LifeExpectancy', source=merged_df.query('Year == 2020'),
                    size=10, alpha=0.7)

hover = HoverTool(tooltips=[("Entity", "@Entity")], renderers=[scatter])
p.add_tools(hover)

show(p)
# Out:
#   <div id="a5789697-0f02-4fd4-bf78-1852875728e5" data-root-id="p1001" style="display: contents;"></div>

# %% [markdown]
# ## **Exporting data**
#
# If we have used Pandas for wrangling or calculation, we might want to export our final data.

# %% [markdown]
# ### **df.to_csv()**
#
# You can use the `.to_csv()` method.
#
# > Pandas can export to many different formats, but `csv` is a very common and useful one.

# %%
merged_df.to_csv('merged_data.csv', index=False)

# %%
merged_df.groupby('Entity')['LifeExpectancy'].mean().sort_values().tail(10)
# Out:
# Entity
# Faroe Islands    74.684574
# Gibraltar        75.039728
# New Zealand      75.130423
# Jersey           75.202542
# Hong Kong        75.331715
# Israel           75.501712
# Guernsey         76.717325
# San Marino       76.879115
# Andorra          77.045154
# Monaco           77.251549
# Name: LifeExpectancy, dtype: float64

# %%
merged_df.query('Year == 2020').sort_values('LifeExpectancy').tail(10)
# Out:
#             Entity Code  Year  LifeExpectancy           GDP
# 10567   Martinique  MTQ  2020         83.0500           NaN
# 16560  Switzerland  CHE  2020         83.0670  7.311087e+11
# 12783       Norway  NOR  2020         83.1951  4.050056e+11
# 10423        Malta  MLT  2020         83.3545  1.343864e+10
# 15722  South Korea  KOR  2020         83.6089  1.626526e+12
# 910      Australia  AUS  2020         84.3239  1.489770e+12
# 8614         Japan  JPN  2020         84.6879  4.375044e+12
# 9991         Macao  MAC  2020         85.1841  2.327113e+10
# 7460     Hong Kong  HKG  2020         85.1968  3.100971e+11
# 11123       Monaco  MCO  2020         86.5380  6.159423e+09

# %%
merged_df.query('GDP == GDP & Year == 2010').sort_values('GDP').head(10)
# Out:
#                       Entity Code  Year  LifeExpectancy          GDP
# 17571                 Tuvalu  TUV  2010         63.9781   30560852.0
# 11690                  Nauru  NRU  2010         59.6402   51766700.0
# 8990                Kiribati  KIR  2010         65.0161  140628940.0
# 10485       Marshall Islands  MHL  2010         63.2261  177714450.0
# 14769  Sao Tome and Principe  STP  2010         65.2486  221134900.0
# 12992                  Palau  PLW  2010         65.5975  234129900.0
# 10969   Micronesia (country)  FSM  2010         71.2328  317470530.0
# 17130                  Tonga  TON  2010         70.3234  391908800.0
# 4569                Dominica  DMA  2010         71.5499  543005700.0
# 18461                Vanuatu  VUT  2010         69.6171  674588740.0

# %%
merged_df

# %% [markdown]
# ## **Continuing the work**
#
# The GDP/Life expectancy data shows no clear correlation because we need to look at GDP per capita.
#
# - Load the population dataset
# - Merge it on Code and Year
# - Make a new cell with GDP per capita
# - Chart the population per capita against the life expectancy.

# %%
population_df = pd.read_csv('population.csv')
population_df
# Out:
#             Entity Code  Year  \
# 0      Afghanistan  AFG  1950
# 1      Afghanistan  AFG  1951
# 2      Afghanistan  AFG  1952
# 3      Afghanistan  AFG  1953
# 4      Afghanistan  AFG  1954
# ...            ...  ...   ...
# 18939     Zimbabwe  ZWE  2019
# 18940     Zimbabwe  ZWE  2020
# 18941     Zimbabwe  ZWE  2021
# 18942     Zimbabwe  ZWE  2022
# 18943     Zimbabwe  ZWE  2023
#
#        Population - Sex: all - Age: all - Variant: estimates
# 0                                                7776182
# 1                                                7879343
# 2                                                7987783
# 3                                                8096703
# 4                                                8207953
# ...                                                  ...
# 18939                                           15271377
# 18940                                           15526888
# 18941                                           15797220
# ...

# %%
population_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18944 entries, 0 to 18943
# Data columns (total 4 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   Entity                                                 18944 non-null  object
#  1   Code                                                   17612 non-null  object
#  2   Year                                                   18944 non-null  int64
#  3   Population - Sex: all - Age: all - Variant: estimates  18944 non-null  int64
# dtypes: int64(2), object(2)
# memory usage: 592.1+ KB

# %%
population_df = population_df.rename(columns={'Population - Sex: all - Age: all - Variant: estimates': 'Population'})
population_df
# Out:
#             Entity Code  Year  Population
# 0      Afghanistan  AFG  1950     7776182
# 1      Afghanistan  AFG  1951     7879343
# 2      Afghanistan  AFG  1952     7987783
# 3      Afghanistan  AFG  1953     8096703
# 4      Afghanistan  AFG  1954     8207953
# ...            ...  ...   ...         ...
# 18939     Zimbabwe  ZWE  2019    15271377
# 18940     Zimbabwe  ZWE  2020    15526888
# 18941     Zimbabwe  ZWE  2021    15797220
# 18942     Zimbabwe  ZWE  2022    16069061
# 18943     Zimbabwe  ZWE  2023    16340829
#
# [18944 rows x 4 columns]

# %%
merged_df2 = pd.merge(merged_df, population_df, on=['Code', 'Year'], how='left')
merged_df2
# Out:
#           Entity_x Code  Year  LifeExpectancy           GDP     Entity_y  \
# 0      Afghanistan  AFG  1950         27.7275           NaN  Afghanistan
# 1      Afghanistan  AFG  1951         27.9634           NaN  Afghanistan
# 2      Afghanistan  AFG  1952         28.4456           NaN  Afghanistan
# 3      Afghanistan  AFG  1953         28.9304           NaN  Afghanistan
# 4      Afghanistan  AFG  1954         29.2258           NaN  Afghanistan
# ...            ...  ...   ...             ...           ...          ...
# 19056     Zimbabwe  ZWE  2017         60.7095  2.096487e+10     Zimbabwe
# 19057     Zimbabwe  ZWE  2018         61.4141  2.201518e+10     Zimbabwe
# 19058     Zimbabwe  ZWE  2019         61.2925  2.062108e+10     Zimbabwe
# 19059     Zimbabwe  ZWE  2020         61.1242  1.900914e+10     Zimbabwe
# 19060     Zimbabwe  ZWE  2021         59.2531  2.061884e+10     Zimbabwe
#
#        Population
# 0       7776182.0
# 1       7879343.0
# 2       7987783.0
# ...

# %%
merged_df3 = merged_df2.query('Entity_x != "World"')

# %%
# prompt: Using dataframe merged_df2: plotly scatter plot for 2020 with population size the point size

import plotly.express as px

# Filter data for the year 2020
df_2020 = merged_df3[merged_df3['Year'] == 2020]

# Create the scatter plot
fig = px.scatter(df_2020,
                 y="LifeExpectancy",
                 x="GDP",
                 size="Population",
                 hover_name="Entity_x",
                 title="Life Expectancy vs. GDP in 2020 (Population Size as Point Size)")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## **Building a correlation matrix**

# %% [markdown]
# ### **What is a correlation matrix?**
#
# A correlation matrix is a type of table that shows the correlation coefficients between multiple variables. It measures the **strength and direction** of a linear relationship between these variables.
#
# Values range between **-1** and **+1**:
#
# **+1**: Indicating a perfect positive correlation, meaning as one variable increases, the other increases in a perfectly linear fashion.
#
# **0**: Indicating no linear correlation between the two variables.
#
# **-1**: Indicating a perfect negative correlation, meaning as one variable increases, the other decreases in a perfectly linear fashion.
#
# ![A correlation matrix](https://www.quanthub.com/wp-content/uploads//correlation_heatmap_food_health-1024x867.png)

# %% [markdown]
# ### **Build a correlation matrix with Pandas and other tools**
#
# As we've seen before, there are many different libraries and approaches to building charts in Python. This is just one way.
#
# The tools we'll use include:
#
# - **Pandas**: Our favourite data library
# - **Numpy**: A [powerful library](https://numpy.org/) used for high-performance computation. Pandas is built on top of Numpy and includes a lot of the functionality.
# - **Matplotlib**: A very customisable charting library. Pandas also includes many of Matplotlib's features.
# - **Seaborn**: Another charting library that extendes the functionality of Matplotlib.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Let's set up a hypothetical dataset:
#
# > Note that we usually load data from a file, but we can also manually set this. A dataframe is a **dictionary of lists**.

# %%
cm_df = pd.DataFrame({
    'age': [25, 32, 47, 51, 62],
    'height': [160, 175, 180, 155, 170],
    'weight': [55, 78, 85, 60, 75],
    'exercise(hrs)': [4, 3, 2, 1, 2]
})

# %%
cm_df
# Out:
#    age  height  weight  exercise(hrs)
# 0   25     160      55              4
# 1   32     175      78              3
# 2   47     180      85              2
# 3   51     155      60              1
# 4   62     170      75              2

# %% [markdown]
# ### df.corr()
#
# Pandas' built-in `corr()` method will calculate the [Pearson Correlation Coefficient](https://en.wikipedia.org/wiki/Pearson_correlation_coefficient).

# %%
corr_matrix = cm_df.corr()
corr_matrix
# Out:
#                     age    height    weight  exercise(hrs)
# age            1.000000  0.079422  0.340598      -0.822454
# height         0.079422  1.000000  0.947566       0.084591
# weight         0.340598  0.947566  1.000000      -0.229316
# exercise(hrs) -0.822454  0.084591 -0.229316       1.000000

# %% [markdown]
# Here we are using Seaborn with Matplotlib. Seaborn has a built-in heatmap chart that can work well for this.

# %%
plt.figure(figsize=(8, 6))

sns.heatmap(corr_matrix)

plt.show()

# %% [markdown]
# Let's change the colours and show the coefficient value to avoid ambiguity.

# %%
plt.figure(figsize=(8, 6))

sns.heatmap(
    corr_matrix,
    annot=True,
    cmap='coolwarm',
    linewidths=0.5
)

plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ### Simplifying the matrix with a mask and numpy.triu()
#
# The correlation matrix is mirrored. We can simplify it by only showing the bottom triangle.
#
# >`np.triu()` calculates the upper trangle of a 2-dimensional grid and sets the rest to 0.

# %%
mask = np.triu(corr_matrix)
mask
# Out:
# array([[ 1.        ,  0.07942206,  0.34059789, -0.82245439],
#        [ 0.        ,  1.        ,  0.94756621,  0.08459099],
#        [ 0.        ,  0.        ,  1.        , -0.22931601],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]])

# %% [markdown]
# To make a mask we don't need values, we just want to identify the upper triangle. We can do it like this:
#
# > `k=1` will include the middle diagonal where a variable lines up with itself.
#
# > `np.ones_like()` makes an array the same shape and type as a given array and fill it with 1.
#
# > `dtype=bool` sets all the ones to `True`/`False`

# %%
mask = np.triu(np.ones_like(corr_matrix, dtype=bool), k=1)
mask
# Out:
# array([[False,  True,  True,  True],
#        [False, False,  True,  True],
#        [False, False, False,  True],
#        [False, False, False, False]])

# %%
plt.figure(figsize=(8, 6))

sns.heatmap(
    corr_matrix,
    mask=mask,
    annot=True,
    cmap='coolwarm',
    linewidths=0.5,
)

plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ### **Your turn**
#
# Make a correlation matrix of the [2025 World Happiness Report](https://happiness-report.s3.us-east-1.amazonaws.com/2025/Data+for+Figure+2.1+(2011%E2%80%932024).xlsx).
# The matrix should include all the countries over all the years.
#
# - Load the file with as a dataframe with `whr_df = pd.read_excel()`
# - There are 2 columns that will not be of use in the a correlation matrix. What are they? Drop them with `whr_df = whr_df.drop(columns=[THE COLUMNS])`
#
# #### **About the data**
#
# - **Life Ladder**: "...It asks respondents to think of a ladder, with the best possible life for them being a 10 and the worst possible life being a 0. They are then asked to rate their own current lives on that 0 to 10 scale."
# - **Positive and Negative affect**: "...**Positive emotions**. Positive affect is given by the average of individual yes or no answers about three emotions: laughter, enjoyment, and interest. **Negative emotions**. Negative affect is given by the average of individual yes or no answers about three emotions: worry, sadness, and anger."

# %%
whr = pd.read_excel('Data+for+Figure+2.1+(2011–2024).xlsx')
whr
# Out:
#       Year  Rank Country name  Ladder score  upperwhisker  lowerwhisker  \
# 0     2024     1      Finland         7.736         7.810         7.662
# 1     2023   143  Afghanistan         1.721         1.775         1.667
# 2     2022   137  Afghanistan         1.859         1.923         1.795
# 3     2021   146  Afghanistan         2.404         2.469         2.339
# 4     2020   150  Afghanistan         2.523         2.596         2.449
# ...    ...   ...          ...           ...           ...           ...
# 1964  2016   138     Zimbabwe         3.875           NaN           NaN
# 1965  2015   131     Zimbabwe         4.193           NaN           NaN
# 1966  2014   115     Zimbabwe         4.610           NaN           NaN
# 1967  2012   103     Zimbabwe         4.827           NaN           NaN
# 1968  2011   142     Zimbabwe         3.978           NaN           NaN
#
#       Explained by: Log GDP per capita  Explained by: Social support  \
# ...

# %%
whr_corr = whr.drop(columns=['Country name', 'Year'])
whr_corr
# Out:
#       Rank  Ladder score  upperwhisker  lowerwhisker  \
# 0        1         7.736         7.810         7.662
# 1      143         1.721         1.775         1.667
# 2      137         1.859         1.923         1.795
# 3      146         2.404         2.469         2.339
# 4      150         2.523         2.596         2.449
# ...    ...           ...           ...           ...
# 1964   138         3.875           NaN           NaN
# 1965   131         4.193           NaN           NaN
# 1966   115         4.610           NaN           NaN
# 1967   103         4.827           NaN           NaN
# 1968   142         3.978           NaN           NaN
#
#       Explained by: Log GDP per capita  Explained by: Social support  \
# 0                                1.749                         1.783
# 1                                0.628                         0.000
# 2                                0.645                         0.000
# ...

# %%
# Calculate the correlation matrix
corr_matrix = whr_corr.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr_matrix, dtype=bool), k=1)

# Slice the matrix and mask to only show the lower triangle (excluding the top row and last column)
# corr_matrix_trimmed = corr_matrix.iloc[1:, :-1]
# mask_trimmed = mask[1:, :-1]

# Plotting the trimmed correlation matrix using seaborn's heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(
    corr_matrix,
    mask=mask,
    annot=True,
    cmap='coolwarm',
    linewidths=0.5,
    vmin=-1,
    vmax=1,


)

plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ## **Working with NetCDF Files**
#
# When researching scientific data and especially climate data, you will very likely come accross `NetCDF` and similar files.
#
# A NetCDF (Network Common Data Form) file is a format designed to store **multi-dimensional** scientific data.
#
# It is a **self-describing file**.
#
# ![NetCDF Diagram](https://web.itu.edu.tr/~tokerem/Presentation/netcdf_1.png)

# %% [markdown]
# ### **Using xarray with NetCDF files**
# Pandas is not suitable for loading NetCDF files and we'll need to use another library instead.
#
# [xarray](https://docs.xarray.dev/en/stable/index.html) has many similarities to Pandas and is also built on top of Numpy.
#
# Download the [example NetCDF file](https://www.unidata.ucar.edu/software/netcdf/examples/ECMWF_ERA-40_subset.nc)

# %%
import xarray as xr

# %%
nc = xr.open_dataset('ECMWF_ERA-40_subset.nc')
nc
# Out:
# <xarray.Dataset> Size: 89MB
# Dimensions:    (longitude: 144, latitude: 73, time: 62)
# Coordinates:
#   * longitude  (longitude) float32 576B 0.0 2.5 5.0 7.5 ... 352.5 355.0 357.5
#   * latitude   (latitude) float32 292B 90.0 87.5 85.0 82.5 ... -85.0 -87.5 -90.0
#   * time       (time) datetime64[ns] 496B 2002-07-01T12:00:00 ... 2002-07-31T...
# Data variables: (12/17)
#     tcw        (time, latitude, longitude) float64 5MB ...
#     tcwv       (time, latitude, longitude) float64 5MB ...
#     lsp        (time, latitude, longitude) float64 5MB ...
#     cp         (time, latitude, longitude) float64 5MB ...
#     msl        (time, latitude, longitude) float64 5MB ...
#     blh        (time, latitude, longitude) float64 5MB ...
#     ...         ...
#     e          (time, latitude, longitude) float64 5MB ...
#     lcc        (time, latitude, longitude) float64 5MB ...
#     mcc        (time, latitude, longitude) float64 5MB ...
# ...

# %%
nc.data_vars
# Out:
# Data variables:
#     tcw      (time, latitude, longitude) float64 5MB ...
#     tcwv     (time, latitude, longitude) float64 5MB ...
#     lsp      (time, latitude, longitude) float64 5MB ...
#     cp       (time, latitude, longitude) float64 5MB ...
#     msl      (time, latitude, longitude) float64 5MB ...
#     blh      (time, latitude, longitude) float64 5MB ...
#     tcc      (time, latitude, longitude) float64 5MB ...
#     p10u     (time, latitude, longitude) float64 5MB ...
#     p10v     (time, latitude, longitude) float64 5MB ...
#     p2t      (time, latitude, longitude) float64 5MB ...
#     p2d      (time, latitude, longitude) float64 5MB ...
#     e        (time, latitude, longitude) float64 5MB ...
#     lcc      (time, latitude, longitude) float64 5MB ...
#     mcc      (time, latitude, longitude) float64 5MB ...
#     hcc      (time, latitude, longitude) float64 5MB ...
#     tco3     (time, latitude, longitude) float64 5MB ...
# ...

# %% [markdown]
# We can get a list of variables and their long names by looping through it. This is a bit of Python code:
#
# > This reads as: For every "var" in nc.data_vars, get the long name attribute of that var and then print the var and its long name.

# %%
for var in nc.data_vars:
    long_name = nc[var].attrs.get('long_name')
    print(var + ': ' + long_name)
# Out:
# tcw: Total column water
# tcwv: Total column water vapour
# lsp: Stratiform precipitation (Large-scale precipitation)
# cp: Convective precipitation
# msl: Mean sea level pressure
# blh: Boundary layer height
# tcc: Total cloud cover
# p10u: 10 metre U wind component
# p10v: 10 metre V wind component
# p2t: 2 metre temperature
# p2d: 2 metre dewpoint temperature
# e: Evaporation
# lcc: Low cloud cover
# mcc: Medium cloud cover
# hcc: High cloud cover
# tco3: Total column ozone
# tp: Total precipitation

# %%
era_df = nc.to_dataframe()
era_df
# Out:
#                                               tcw       tcwv       lsp   cp  \
# longitude latitude time
# 0.0        90.0    2002-07-01 12:00:00  10.152713  10.103384       NaN  NaN
#                    2002-07-01 18:00:00        NaN        NaN  0.000076  0.0
#                    2002-07-02 12:00:00  10.667101  10.623612       NaN  NaN
#                    2002-07-02 18:00:00        NaN        NaN  0.000110  0.0
#                    2002-07-03 12:00:00  11.292196  11.102699       NaN  NaN
# ...                                           ...        ...       ...  ...
# 357.5     -90.0    2002-07-29 18:00:00        NaN        NaN  0.000035  0.0
#                    2002-07-30 12:00:00   0.237592   0.228353       NaN  NaN
#                    2002-07-30 18:00:00        NaN        NaN  0.000104  0.0
#                    2002-07-31 12:00:00   0.201140   0.196502       NaN  NaN
#                    2002-07-31 18:00:00        NaN        NaN  0.000060  0.0
#
# ...

# %% [markdown]
# ### **Building a correlation matrix from a NetCDF file**

# %%
era_df = era_df.reset_index()

# %%
era_df = era_df.drop(columns=['time', 'latitude', 'longitude'])
era_df
# Out:
#               tcw       tcwv       lsp   cp            msl         blh  \
# 0       10.152713  10.103384       NaN  NaN  100476.773702         NaN
# 1             NaN        NaN  0.000076  0.0            NaN  439.210606
# 2       10.667101  10.623612       NaN  NaN  100364.687500         NaN
# 3             NaN        NaN  0.000110  0.0            NaN  453.455465
# 4       11.292196  11.102699       NaN  NaN  100197.332986         NaN
# ...           ...        ...       ...  ...            ...         ...
# 651739        NaN        NaN  0.000035  0.0            NaN   39.158415
# 651740   0.237592   0.228353       NaN  NaN  100223.675826         NaN
# 651741        NaN        NaN  0.000104  0.0            NaN   69.387963
# 651742   0.201140   0.196502       NaN  NaN  100670.987582         NaN
# 651743        NaN        NaN  0.000060  0.0            NaN   17.954235
#
#              tcc      p10u      p10v         p2t         p2d         e  \
# ...

# %%
era_df_corr = era_df.corr()
era_df_corr
# Out:
#            tcw      tcwv       lsp        cp       msl       blh       tcc  \
# tcw   1.000000  0.999934       NaN       NaN  0.261330       NaN       NaN
# tcwv  0.999934  1.000000       NaN       NaN  0.262970       NaN       NaN
# lsp        NaN       NaN  1.000000  0.388901       NaN -0.016818  0.207905
# cp         NaN       NaN  0.388901  1.000000       NaN  0.047842  0.148518
# msl   0.261330  0.262970       NaN       NaN  1.000000       NaN       NaN
# blh        NaN       NaN -0.016818  0.047842       NaN  1.000000 -0.146195
# tcc        NaN       NaN  0.207905  0.148518       NaN -0.146195  1.000000
# p10u -0.131114 -0.132029       NaN       NaN -0.135934       NaN       NaN
# p10v  0.054006  0.055121       NaN       NaN  0.041080       NaN       NaN
# p2t   0.714447  0.715253       NaN       NaN  0.274827       NaN       NaN
# p2d   0.750895  0.751184       NaN       NaN  0.273556       NaN       NaN
# ...

# %%
era_df_corr = era_df_corr.fillna(0)
era_df_corr
# Out:
#            tcw      tcwv       lsp        cp       msl       blh       tcc  \
# tcw   1.000000  0.999934  0.000000  0.000000  0.261330  0.000000  0.000000
# tcwv  0.999934  1.000000  0.000000  0.000000  0.262970  0.000000  0.000000
# lsp   0.000000  0.000000  1.000000  0.388901  0.000000 -0.016818  0.207905
# cp    0.000000  0.000000  0.388901  1.000000  0.000000  0.047842  0.148518
# msl   0.261330  0.262970  0.000000  0.000000  1.000000  0.000000  0.000000
# blh   0.000000  0.000000 -0.016818  0.047842  0.000000  1.000000 -0.146195
# tcc   0.000000  0.000000  0.207905  0.148518  0.000000 -0.146195  1.000000
# p10u -0.131114 -0.132029  0.000000  0.000000 -0.135934  0.000000  0.000000
# p10v  0.054006  0.055121  0.000000  0.000000  0.041080  0.000000  0.000000
# p2t   0.714447  0.715253  0.000000  0.000000  0.274827  0.000000  0.000000
# p2d   0.750895  0.751184  0.000000  0.000000  0.273556  0.000000  0.000000
# ...

# %%
plt.figure(figsize=(15, 10))

sns.heatmap(
    era_df_corr,
    annot=True,
    cmap='coolwarm',
    linewidths=0.5,
    vmin=-1,
    vmax=1,
)

plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ### **Theming our correlation matrix**
#
# Although Seaborn has many built-in themes we might want to try something else. The `pypalettes` library has 2500+ colour maps to choose from.

# %% [markdown]
# ### **Installing libraries**
# `pypalettes` isn't included by default in our Colab Python environment, but we can install it and [thousands of other libraries](https://pypi.org/) quite easily.
#
# > This command would only need to be run once and can be commented out afterwards.

# %%
# !pip install pypalettes
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/366.0 kB ? eta -:--:--
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺ 358.4/366.0 kB 10.7 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 366.0/366.0 kB 6.6 MB/s eta 0:00:00
# ...

# %% [markdown]
# ### **Finding and including palettes**
#
# Visit [Python Color Palette Finder](https://python-graph-gallery.com/color-palette-finder/) and choose a colour scheme you like.
#
# use `cmap=load_cmap('<scheme>',cmap_type='continuous')` to include it.

# %%
from pypalettes import load_cmap

plt.figure(figsize=(15, 10))

sns.heatmap(
    era_df_corr,
    annot=True,
    cmap=load_cmap('Anemone', cmap_type='continuous'),
    linewidths=0.5,
    vmin=-1,
    vmax=1,
)

plt.title('Correlation Matrix')
plt.show()
# Out:
# <frozen importlib._bootstrap>:1047: ImportWarning:
#
# _PyDrive2ImportHook.find_spec() not found; falling back to find_module()
#
# <frozen importlib._bootstrap>:1047: ImportWarning:
#
# _PyDriveImportHook.find_spec() not found; falling back to find_module()
#
# <frozen importlib._bootstrap>:1047: ImportWarning:
#
# _BokehImportHook.find_spec() not found; falling back to find_module()

# %%
from pypalettes import load_cmap

mask = np.triu(np.ones_like(era_df_corr, dtype=bool), k=1)

plt.figure(figsize=(15, 10))

sns.heatmap(
    era_df_corr,
    mask=mask,
    annot=True,
    cmap=load_cmap('Anemone', cmap_type='continuous'),
    linewidths=0.5,
    vmin=-1,
    vmax=1,
)

plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# # **Appendix**

# %% [markdown]
# ### **Python basics**

# %% [markdown]
# #### **Variables**

# %%
var1 = "Hello World"
var2 = 3
var3 = 6

# %%
var1

# %% [markdown]
# #### **Operators and calulculation**

# %%
var2 + var3

# %%
var2 * var3

# %%
var3 / var2

# %% [markdown]
# #### **Lists**

# %%
list1 = ["apple","banana","cherry"]

# %%
list1[0]

# %%
list1.append("orange")
list1

# %% [markdown]
# #### **Dictionaries**

# %%
person = {
  "name": "John",
  "age": 36,
  "country": "Norway"
}

# %%
person['name']

# %% [markdown]
# #### **Functions**

# %%
def add_it_up(number1, number2):
  print(str(number1) + " + " + str(number2) + " = " + str(number1 + number2))

add_it_up(10, 20)
